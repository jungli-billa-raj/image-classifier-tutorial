# %%
import torch 
import numpy as np

# %%
data = [[1,2],[3,4]]
x_data = torch.tensor(data)

# %%
x_data
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
np_array = np.array(data)
x_np = torch.from_numpy(np_array)
x_np
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
shape = (2, 3,)
rand_tensor = torch.rand(shape)
ones_tensor = torch.ones(shape)
zeros_tensor = torch.zeros(shape)

print(f"Random Tensor: \n {rand_tensor} \n")
print(f"Ones Tensor: \n {ones_tensor} \n")
print(f"Zeros Tensor: \n {zeros_tensor}")
# Out:
# Random Tensor:
#  tensor([[0.7789, 0.8051, 0.4269],
#         [0.1689, 0.6982, 0.5328]])
#
# Ones Tensor:
#  tensor([[1., 1., 1.],
#         [1., 1., 1.]])
#
# Zeros Tensor:
#  tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
tensor = torch.rand(3,4)

print(tensor.shape)
print(tensor.dtype)
print(tensor.device)
print(tensor)
# Out:
# torch.Size([3, 4])
# torch.float32
# cpu
# tensor([[0.2915, 0.2474, 0.7539, 0.3329],
#         [0.7840, 0.6539, 0.0367, 0.3870],
#         [0.9524, 0.4358, 0.6484, 0.4625]])

# %%
torch.cuda.is_available()
# Out:
# False
